# %%
# Importing essential libraries for data manipulation and analysis
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
#Label extraction on training data
# Import the os module to work with file paths and directories
import os
# Create an empty list to store labels
labels = []

# Iterate through each folder and assign labels
# Assuming each folder corresponds to a different category

for i in os.listdir('C:/Users/Simanto/Downloads/Compressed/archive/data/train/0'):
    labels.append(0)
for i in os.listdir('C:/Users/Simanto/Downloads/Compressed/archive/data/train/1'):
    labels.append(1)
for i in os.listdir('C:/Users/Simanto/Downloads/Compressed/archive/data/train/2'):
    labels.append(2)
for i in os.listdir('C:/Users/Simanto/Downloads/Compressed/archive/data/train/3'):
    labels.append(3)
for i in os.listdir('C:/Users/Simanto/Downloads/Compressed/archive/data/train/4'):
    labels.append(4)
for i in os.listdir('C:/Users/Simanto/Downloads/Compressed/archive/data/train/5'):
    labels.append(5)
for i in os.listdir('C:/Users/Simanto/Downloads/Compressed/archive/data/train/6'):
    labels.append(6)

# %%
#feature extraction on training data
# Import the OpenCV library for image processing
import cv2
#loc1 = '#feature extraction on training data
import cv2

# Define the file paths for each class or category
loc1 = 'C:/Users/Simanto/Downloads/Compressed/archive/data/train/0'
loc2 = 'C:/Users/Simanto/Downloads/Compressed/archive/data/train/1'
loc3 = 'C:/Users/Simanto/Downloads/Compressed/archive/data/train/2'
loc4 = 'C:/Users/Simanto/Downloads/Compressed/archive/data/train/3'
loc5 = 'C:/Users/Simanto/Downloads/Compressed/archive/data/train/4'
loc6 = 'C:/Users/Simanto/Downloads/Compressed/archive/data/train/5'
loc7 = 'C:/Users/Simanto/Downloads/Compressed/archive/data/train/6'

# Create an empty list to store image features
features = []
# Import the tqdm library for progress tracking
from tqdm import tqdm

# Loop through each directory and load images from each class
# Assuming the images are grayscale (0 means loading images in grayscale)

for i in tqdm(os.listdir(loc1)):
    features.append(cv2.imread(os.path.join(loc1,i),0))
    
for i in tqdm(os.listdir(loc2)):
    features.append(cv2.imread(os.path.join(loc2,i),0))
    
for i in tqdm(os.listdir(loc3)):
    features.append(cv2.imread(os.path.join(loc3,i),0))
    
for i in tqdm(os.listdir(loc4)):
    features.append(cv2.imread(os.path.join(loc4,i),0))
    
for i in tqdm(os.listdir(loc5)):
    features.append(cv2.imread(os.path.join(loc5,i),0))
    
for i in tqdm(os.listdir(loc6)):
    features.append(cv2.imread(os.path.join(loc6,i),0))
    
for i in tqdm(os.listdir(loc7)):
    features.append(cv2.imread(os.path.join(loc7,i),0))
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 4965/4965 [00:01<00:00, 4707.09it/s]

# %%
#Label extraction on testing data
# Import the os module to work with file paths and directories
import os

# Create an empty list to store labels for the test data
labels_test = []

# Iterate through each folder and assign labels for the test data
# Assuming each folder corresponds to a different category (0 to 6)
for i in os.listdir('C:/Users/Simanto/Downloads/Compressed/archive/data/test/0'):
    labels_test.append(0)
for i in os.listdir('C:/Users/Simanto/Downloads/Compressed/archive/data/test/1'):
    labels_test.append(1)
for i in os.listdir('C:/Users/Simanto/Downloads/Compressed/archive/data/test/2'):
    labels_test.append(2)
for i in os.listdir('C:/Users/Simanto/Downloads/Compressed/archive/data/test/3'):
    labels_test.append(3)
for i in os.listdir('C:/Users/Simanto/Downloads/Compressed/archive/data/test/4'):
    labels_test.append(4)
for i in os.listdir('C:/Users/Simanto/Downloads/Compressed/archive/data/test/5'):
    labels_test.append(5)
for i in os.listdir('C:/Users/Simanto/Downloads/Compressed/archive/data/test/6'):
    labels_test.append(6)

# %%
#feature extraction on testing data
# Import the OpenCV library for image processing
import cv2

# Define the file paths for each class or category in the testing dataset
loc1 = 'C:/Users/Simanto/Downloads/Compressed/archive/data/test/0'
loc2 = 'C:/Users/Simanto/Downloads/Compressed/archive/data/test/1'
loc3 = 'C:/Users/Simanto/Downloads/Compressed/archive/data/test/2'
loc4 = 'C:/Users/Simanto/Downloads/Compressed/archive/data/test/3'
loc5 = 'C:/Users/Simanto/Downloads/Compressed/archive/data/test/4'
loc6 = 'C:/Users/Simanto/Downloads/Compressed/archive/data/test/5'
loc7 = 'C:/Users/Simanto/Downloads/Compressed/archive/data/test/6'

# Create an empty list to store image features for the testing dataset
test_features = []
# Import the tqdm library for progress tracking
from tqdm import tqdm

# Loop through each directory and load images from each class in the testing dataset
# Assuming the images are grayscale (0 means loading images in grayscale)

for i in tqdm(os.listdir(loc1)):
    test_features.append(cv2.imread(os.path.join(loc1,i),0))
    
for i in tqdm(os.listdir(loc2)):
    test_features.append(cv2.imread(os.path.join(loc2,i),0))
    
for i in tqdm(os.listdir(loc3)):
    test_features.append(cv2.imread(os.path.join(loc3,i),0))
    
for i in tqdm(os.listdir(loc4)):
    test_features.append(cv2.imread(os.path.join(loc4,i),0))
    
for i in tqdm(os.listdir(loc5)):
    test_features.append(cv2.imread(os.path.join(loc5,i),0))
    
for i in tqdm(os.listdir(loc6)):
    test_features.append(cv2.imread(os.path.join(loc6,i),0))
    
for i in tqdm(os.listdir(loc7)):
    test_features.append(cv2.imread(os.path.join(loc7,i),0))
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 626/626 [00:00<00:00, 1517.44it/s]

# %%
# Import the Pandas library for data manipulation
import pandas as pd
# Create empty DataFrames to store training and testing data
train_data = pd.DataFrame()
test_data = pd.DataFrame()

# %%
# Add a column 'emotion' to the training data DataFrame and assign the 'labels' list
train_data['emotion'] = labels
# Add a column 'pixel_values' to the training data DataFrame and assign the 'features' list
train_data['pixel_values'] = features
# Add a column 'emotion' to the testing data DataFrame and assign the 'labels_test' list
test_data['emotion'] = labels_test
# Add a column 'pixel_values' to the testing data DataFrame and assign the 'test_features' list
test_data['pixel_values'] = test_features

# %%
train_data.head()
# Out:
#    emotion                                       pixel_values
# 0        0  [[70, 80, 82, 72, 58, 58, 60, 63, 54, 58, 60, ...
# 1        0  [[151, 150, 147, 155, 148, 133, 111, 140, 170,...
# 2        0  [[30, 24, 21, 23, 25, 25, 49, 67, 84, 103, 120...
# 3        0  [[32, 25, 19, 55, 46, 35, 34, 48, 92, 101, 33,...
# 4        0  [[223, 218, 199, 191, 202, 205, 194, 133, 103,...

# %%
test_data.head()
# Out:
#    emotion                                       pixel_values
# 0        0  [[170, 118, 101, 88, 88, 75, 78, 82, 66, 74, 6...
# 1        0  [[138, 142, 66, 80, 87, 92, 97, 99, 88, 73, 72...
# 2        0  [[245, 245, 239, 122, 144, 101, 33, 37, 84, 13...
# 3        0  [[215, 218, 222, 220, 221, 226, 218, 215, 216,...
# 4        0  [[58, 52, 55, 62, 59, 42, 40, 45, 43, 39, 40, ...

# %%
# List of emotion labels
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# Function to set up the bar chart
def setup_axe(axe,df,title):
     # Plot the emotion counts as a bar chart
    df['emotion'].value_counts(sort=False).plot(ax=axe, kind='bar', rot=0)
    axe.set_xticklabels(emotion_labels)
    axe.set_xlabel("Emotions")
    axe.set_ylabel("Count")
    axe.set_title(title)
    
    # set individual bar lables using above list
    for i in axe.patches:
         axe.text(i.get_x()-.05, i.get_height()+120, \
                str(round((i.get_height()), 2)), fontsize=14, color='red',
                    rotation=0)

import matplotlib.pyplot as plt   
# Create a figure with two subplots (one for training data and one for testing data)
fig, axes = plt.subplots(1,2, figsize=(20,8), sharey=True)

# Set up the bar charts for training and testing data
setup_axe(axes[0],train_data,'train')
setup_axe(axes[1],test_data,'test')
# Display the plots
plt.show()

# %%
# !pip install tensorflow
# !pip install keras

# %%
# Import the required libraries
import numpy as np
from tensorflow.keras.utils import to_categorical  # Import to_categorical from tensorflow.keras.utils
# Reshape the training and testing image data to the appropriate shape (48x48 pixels, 1 channel)
features = np.array(features).reshape(-1, 48, 48, 1)
test_features = np.array(test_features).reshape(-1, 48, 48, 1)

# Normalize the pixel values by dividing them by 255 to scale them between 0 and 1
features = features / 255
test_features = test_features / 255

# Convert the emotion labels to one-hot encoded vectors
labels = to_categorical(labels)  # Use to_categorical from tensorflow.keras.utils
labels_test = to_categorical(labels_test)

# %%
# Print the shape of the training features array
print('Training features shape ',features.shape)
# Print the shape of the training labels array
print('Training labels shape',labels.shape)
# Print the shape of the testing features array
print('Testing features shape ',test_features.shape)
# Print the shape of the testing labels array
print('Testing labels shape',labels_test.shape)
# Out:
# Training features shape  (28709, 48, 48, 1)
# Training labels shape (28709, 7)
# Testing features shape  (3589, 48, 48, 1)
# Testing labels shape (3589, 7)

# %%
# Import the necessary components from Keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
from keras.optimizers import *
from sklearn.metrics import accuracy_score

# %%
# Create a Sequential model
model = Sequential()
# Define the input shape
input_shape = (48,48,1)
# Convolutional layers with ReLU activation and batch normalization
model.add(Conv2D(64, (5, 5), input_shape=input_shape,activation='relu', padding='same'))
model.add(Conv2D(64, (5, 5), activation='relu', padding='same'))
model.add(BatchNormalization())
# Max pooling layer
model.add(MaxPooling2D(pool_size=(2, 2)))
# More convolutional layers with ReLU activation and batch normalization
model.add(Conv2D(128, (5, 5),activation='relu',padding='same'))
model.add(Conv2D(128, (5, 5),activation='relu',padding='same'))
model.add(BatchNormalization())
# Another max pooling layer
model.add(MaxPooling2D(pool_size=(2, 2)))
# More convolutional layers with ReLU activation and batch normalization
model.add(Conv2D(256, (3, 3),activation='relu',padding='same'))
model.add(Conv2D(256, (3, 3),activation='relu',padding='same'))
model.add(BatchNormalization())
# Another max pooling layer
model.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the data
model.add(Flatten())
# Fully connected layers with batch normalization and ReLU activation
model.add(Dense(128))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# Output layer with softmax activation for classification
model.add(Dense(7))
model.add(Activation('softmax'))
# Compile the model with categorical cross-entropy loss, accuracy metric, and the Adam optimizer  
model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 48, 48, 64)        1664
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        102464
#
#  batch_normalization (Batch  (None, 48, 48, 64)        256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 64)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       204928
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       409728
#
#  batch_normalization_1 (Bat  (None, 24, 24, 128)       512
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 128)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batch_normalization_2 (Bat  (None, 12, 12, 256)       1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 256)         0
#  g2D)
# ...

# %%
# Import the EarlyStopping callback from Keras
from keras.callbacks import EarlyStopping

# Create an EarlyStopping callback with specific parameters:
# - Monitor 'val_loss': It monitors the validation loss.
# - Patience: It waits for 10 epochs with no improvement before stopping.
# - Mode 'min': It considers 'val_loss' to minimize. You can use 'max' if monitoring a metric like accuracy.
# - restore_best_weights=True: It restores the model's weights to the best values when stopping.
es = EarlyStopping(monitor='val_loss', patience = 10, mode = 'min', restore_best_weights=True)

# %%
# Train the model using the training data and validation data
history = model.fit(x=features, 
            y=labels, 
            batch_size=64,
            steps_per_epoch=len(features) / 64,
            epochs=1, 
            verbose=1, 
            callbacks = [es], # EarlyStopping callback to monitor and stop training if necessary
            validation_data=(test_features,labels_test),
            shuffle=True)

# Save the trained model to a file
emotion_model.save('fer2013_emotion_model.h5')

# Save the model in the recommended .keras format
emotion_model.save('fer2013_emotion_model.keras')
# Out:
# 448/448 [==============================] - 1157s 3s/step - loss: 1.6772 - accuracy: 0.3474 - val_loss: 1.6236 - val_accuracy: 0.3809
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 13
#       2 history = model.fit(x=features,
#       3             y=labels,
#       4             batch_size=64,
#    (...)
#       9             validation_data=(test_features,labels_test),
#      10             shuffle=True)
#      12 # Save the trained model to a file
# ---> 13 emotion_model.save('fer2013_emotion_model.h5')
#      15 # Save the model in the recommended .keras format
#      16 emotion_model.save('fer2013_emotion_model.keras')
#
# NameError: name 'emotion_model' is not defined

# %%
# Save the trained model to a file
model.save('fer2013_emotion_model.h5')
# Out:
# C:\Users\Simanto\anaconda3\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Save the model in the recommended .keras format
model.save('fer2013_emotion_model.keras')

# %%
import matplotlib.pyplot as plt
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
test_true = np.argmax(labels_test, axis=1)
test_pred = np.argmax(model.predict(test_features), axis=1)
print("CNN Model Accuracy on testing data: {:.4f}".format(accuracy_score(test_true, test_pred)))
# Out:
# 113/113 [==============================] - 45s 394ms/step
# CNN Model Accuracy on testing data: 0.3809

# %%
from sklearn import metrics
# Predicted values
y_pred = test_pred
# Actual values
y_act = test_true 
# Printing the confusion matrix
# The columns will show the instances predicted for each label,
# and the rows will show the actual number of instances for each label.
print(metrics.confusion_matrix(y_act, y_pred, labels=[0,1,2,3,4,5,6]))
# Printing the precision and recall, among other metrics
print(metrics.classification_report(y_act, y_pred, labels=[0,1,2,3,4,5,6]))
# Out:
# [[ 65   0  53 139  61   5 168]
#  [  5   0   4  20   6   0  20]
#  [ 32   0  77 165  72   8 174]
#  [ 22   1  25 707  38   2  84]
#  [ 23   0  33 198 133   1 206]
#  [ 30   0 103  78  31  61 113]
#  [ 16   0  52 166  67   1 324]]
#               precision    recall  f1-score   support
#
#            0       0.34      0.13      0.19       491
#            1       0.00      0.00      0.00        55
#            2       0.22      0.15      0.18       528
#            3       0.48      0.80      0.60       879
#            4       0.33      0.22      0.27       594
#            5       0.78      0.15      0.25       416
#            6       0.30      0.52      0.38       626
#
#     accuracy                           0.38      3589
#    macro avg       0.35      0.28      0.27      3589
# weighted avg       0.39      0.38      0.34      3589

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_act, y_pred)
# Normalise
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(cmn, annot=True, fmt='.2f', xticklabels=emotion_labels, yticklabels=emotion_labels)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show(block=False)

# %%
objects = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
y_pos = np.arange(len(objects))
print(y_pos)
# Out:
# [0 1 2 3 4 5 6]

# %%
import matplotlib.pyplot as plt
def emotion_analysis(emotions):
    objects = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']
    y_pos = np.arange(len(objects))
    plt.bar(y_pos, emotions, align='center', alpha=0.9)
    plt.tick_params(axis='x', which='both', pad=10,width=4,length=10)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    plt.show()

# %%
# Import necessary libraries
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from skimage import io

# Define a function to predict emotions from an image
def predict_image(pic):
    # Load and preprocess the input image
    img = image.load_img(pic, grayscale=True, target_size=(48, 48))
    show_img=image.load_img(pic, grayscale=False, target_size=(200, 200))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis = 0)

    x /= 255

      # Make predictions using the trained model
    custom = model.predict(x)
     # Display the emotion analysis
    emotion_analysis(custom[0])

    x = np.array(x, 'float32')
    x = x.reshape([48, 48]);

     # Display the processed image
    plt.gray()
    plt.imshow(show_img)
    plt.show()

    # Determine the predicted emotion based on the model's output
    m=0.000000000000000000001
    a=custom[0]
    for i in range(0,len(a)):
        if a[i]>m:
            m=a[i]
            ind=i
        
    print('Expression Prediction:',objects[ind])
# Out:
# C:\Users\Simanto\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
# Call the predict_image function with the path to an image to make predictions
predict_image('D:/299 Final/a2.jpeg')
# Out:
# C:\Users\Simanto\anaconda3\Lib\site-packages\keras\src\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(
# 1/1 [==============================] - 0s 70ms/step
# Expression Prediction: fear

# %%
predict_image('C:/Users/Hp/Documents/Downloads/archive/data/val/2/29026.png')
# Out:
# 1/1 [==============================] - 0s 66ms/step
# Expression Prediction: fear

# %%
predict_image('C:/Users/Hp/Documents/Downloads/archive/data/val/1/28953.png')
# Out:
# 1/1 [==============================] - 0s 86ms/step
# Expression Prediction: disgust

# %%
predict_image('C:/Users/Hp/Documents/Downloads/archive/data/val/0/28749.png')
# Out:
# 1/1 [==============================] - 0s 105ms/step
# Expression Prediction: angry

# %%
predict_image('C:/Users/Hp/Documents/Downloads/archive/data/val/4/28865.png')
# Out:
# 1/1 [==============================] - 0s 69ms/step
# Expression Prediction: sad

# %%
predict_image('C:/Users/Hp/Documents/Downloads/archive/data/val/5/28829.png')
# Out:
# 1/1 [==============================] - 0s 78ms/step
# Expression Prediction: surprise

# %%
predict_image('C:/Users/Hp/Documents/Downloads/archive/data/val/6/28769.png')
# Out:
# 1/1 [==============================] - 0s 72ms/step
# Expression Prediction: neutral

# %%
import tensorflow as tf  # Import TensorFlow# Load your emotion prediction model
emotion_model = tf.keras.models.load_model('fer2013_emotion_model.keras')

# %%
def detect_faces(frame):
    # Load a pre-trained face detection classifier
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

    # Convert the frame to grayscale for face detection
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    return faces

# %%
def predict_emotions(frame, faces):
    emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

    for (x, y, w, h) in faces:
        # Extract the face region from the frame
        face_roi = frame[y:y + h, x:x + w]
        # Preprocess the face image (resize and convert to grayscale)
        face_roi = cv2.cvtColor(cv2.resize(face_roi, (48, 48)), cv2.COLOR_BGR2GRAY)
        face_roi = np.expand_dims(face_roi, axis=-1)
        face_roi = np.expand_dims(face_roi, axis=0)
        # Predict emotion
        predictions = emotion_model.predict(face_roi)
        predicted_emotion = emotion_labels[np.argmax(predictions)]

        # Draw a rectangle around the detected face
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Display the predicted emotion text above the rectangle
        cv2.putText(frame, predicted_emotion, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

# %%
# Open a connection to the webcam (0 indicates the default camera)
cap = cv2.VideoCapture(0)

while True:
    # Read a frame from the webcam
    ret, frame = cap.read()

    # Detect faces in the frame
    faces = detect_faces(frame)

    # Predict emotions and draw rectangles on the faces
    predict_emotions(frame, faces)

    # Display the frame with emotion predictions
    cv2.imshow('Emotion Detection', frame)

    # Break the loop if the 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 36ms/step
